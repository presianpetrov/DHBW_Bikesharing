# %%
import os
import glob
import pandas as pd
import numpy as np
import seaborn as sns

# %%
path = (r"trips")
allFiles = glob.glob(os.path.join(path,"*.csv"))

# %%
np_array_list = []
for file_ in allFiles:
    df = pd.read_csv(file_,index_col=None, header=0)
    np_array_list.append(df.values)

comb_np_array = np.vstack(np_array_list)
all_trips = pd.DataFrame(comb_np_array)

all_trips.columns = ['index','trip_id','bike_id','trip_duration','trip_start_time','trip_end_time',
         'from_station','from_station_id','from_station_mode','from_lat','from_long',
         'to_station','to_station_id','to_station_mode','to_lat','to_long' ]

# %%
# remove NaN and negative trip size
all_trips = all_trips.dropna(subset=['trip_duration'])
all_trips['trip_start_time'] = pd.to_datetime(all_trips['trip_start_time'])
all_trips['trip_end_time'] = pd.to_datetime(all_trips['trip_end_time'])
all_trips['trip_duration'] = pd.to_timedelta(all_trips['trip_duration'], unit='s')
all_trips = all_trips[all_trips['trip_duration'] > pd.Timedelta(0)]

# %%
all_trips
# Out:
#        index      trip_id bike_id   trip_duration     trip_start_time  \
# 2      17644  20240220002  325006 0 days 03:50:00 2024-02-20 11:55:03
# 3      17722  20240220003  325006 0 days 00:15:00 2024-02-20 22:15:05
# 6      44849  20240220006   32501 0 days 00:15:01 2024-02-20 21:05:05
# 7      44872  20240220007   32501 0 days 00:40:00 2024-02-20 23:10:04
# 9      21354  20240220009  325011 0 days 02:40:00 2024-02-20 13:05:03
# ...      ...          ...     ...             ...                 ...
# 67904  59313  20240240785   35684 0 days 00:20:01 2024-02-26 15:25:03
# 67905  59318  20240240786   35684 0 days 00:09:59 2024-02-26 16:05:05
# 67906  59319  20240240787   35684 0 days 00:15:00 2024-02-26 16:15:04
# 67907  59375  20240240788   35684 0 days 00:09:59 2024-02-26 21:05:05
# 67908  59492  20240240789   35684 0 days 00:14:59 2024-02-27 06:55:05
#
#             trip_end_time                    from_station from_station_id  \
# 2     2024-02-20 15:45:03                     BIKE 325006               0
# 3     2024-02-20 22:30:05         Rotteckring (FreloPlus)            3692
# 6     2024-02-20 21:20:06                     Lorettobad             3740
# 7     2024-02-20 23:50:04                    Hauptbahnhof            3691
# 9     2024-02-20 15:45:03                     BIKE 325011               0
# ...                   ...                             ...             ...
# 67904 2024-02-26 15:45:04  Basler Landstraße/Blumenstraße            3684
# 67905 2024-02-26 16:15:04                    Moltkestraße            3674
# 67906 2024-02-26 16:30:04               Engelbergerstraße            3658
# 67907 2024-02-26 21:15:04                    Wiwilibrücke            3846
# 67908 2024-02-27 07:10:04     Heinrich-von-Stephan-Straße            3742
#
#       from_station_mode   from_lat from_long  \
# 2              floating  48.035831  7.807582
# 3               station    47.9961   7.84616
# 6               station  47.984584  7.840984
# 7               station   47.99743    7.8425
# 9              floating  48.035773  7.807632
# ...                 ...        ...       ...
# 67904           station  47.982453  7.802845
# 67905           station  47.995016  7.843514
# 67906           station  47.997058  7.834818
# 67907           station  47.995206   7.84081
# 67908           station  47.989491  7.836953
#
#                              to_station to_station_id to_station_mode  \
# 2               Rotteckring (FreloPlus)        3692.0         station
# 3      Studentendorf Vauban (FreloPlus)        3699.0         station
# 6                          Hauptbahnhof        3691.0         station
# 7             Laßbergstraße (FreloPlus)        3737.0         station
# 9               Rotteckring (FreloPlus)        3692.0         station
# ...                                 ...           ...             ...
# 67904                      Moltkestraße        3674.0         station
# 67905                 Engelbergerstraße        3658.0         station
# 67906                      Wiwilibrücke        3846.0         station
# 67907       Heinrich-von-Stephan-Straße        3742.0         station
# 67908                Peter-Thumb-Straße        3744.0         station
#
#           to_lat   to_long
# 2        47.9961   7.84616
# 3        47.9761    7.8284
# 6       47.99743    7.8425
# 7       47.98464   7.89354
# 9        47.9961   7.84616
# ...          ...       ...
# 67904  47.995016  7.843514
# 67905  47.997058  7.834818
# 67906  47.995206   7.84081
# 67907  47.989491  7.836953
# 67908   47.97998   7.83215
#
# [52222 rows x 16 columns]

# %%
all_trips.groupby([all_trips['trip_end_time'].dt.date])['trip_id'].size()
# Out:
# trip_end_time
# 2024-02-20     8142
# 2024-02-21    10465
# 2024-02-22    10438
# 2024-02-23     8637
# 2024-02-24     5787
# 2024-02-25     3863
# 2024-02-26     3688
# 2024-02-27      839
# 2024-02-29      363
# Name: trip_id, dtype: int64

# %%
all_trips.to_csv('all_trips.csv', index=False)
